# %%
import os
import pickle
import random
import math
import pandas as pd
import numpy as np
from kiwipiepy import Kiwi
import sqlite3

BASE_DIR = os.path.join('..')
DATA_DIR = os.path.join(BASE_DIR, 'data_final')
DB_DIR = os.path.join(BASE_DIR, 'database_final')

DATA_PATH = os.path.join(DATA_DIR, 'sampled_data_final.pkl')
DB_PATH = os.path.join(DB_DIR, 'search_index_final.db')

QUERIES_PATH = os.path.join(BASE_DIR, 'data', 'queries.pkl')
QRELS_PATH = os.path.join(BASE_DIR, 'data', 'qrels.pkl')

df = pd.read_pickle(DATA_PATH)

if '_id' in df.columns:
    df.set_index('_id', inplace=True)
elif 'doc_id' in df.columns:
    df.set_index('doc_id', inplace=True)
df.index = df.index.astype(str)

with open(QUERIES_PATH, 'rb') as f:
    queries_data = pickle.load(f)
with open(QRELS_PATH, 'rb') as f:
    qrels_data = pickle.load(f)

qrels_dict = {}
for item in qrels_data:
    qid, doc_id = str(item.get('query-id')), str(item.get('corpus-id'))
    if qid and doc_id:
        qrels_dict.setdefault(qid, set()).add(doc_id)

queries_map = {str(q['_id']): q['text'] for q in queries_data if '_id' in q}

kiwi = Kiwi(num_workers=-1)

def tokenize_query(text):
    try:
        return [t.form for t in kiwi.tokenize(text) if t.tag in ['NNG', 'NNP', 'VV', 'VA', 'MAG']]
    except:
        return []

conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

total_docs = len(df)
avg_dl = df['doc_length'].mean()

def get_term_idf(term):
    cursor.execute('SELECT COUNT(DISTINCT doc_id) FROM inverted_index WHERE term=?', (term,))
    df_val = cursor.fetchone()[0]
    return math.log((total_docs - df_val + 0.5) / (df_val + 0.5) + 1) if df_val > 0 else 0

def calculate_scores(query_tokens, k1=5.5, b=0.99):
    scores = {}
    for term in query_tokens:
        idf = get_term_idf(term)
        if idf <= 0: continue

        cursor.execute('SELECT doc_id, tf FROM inverted_index WHERE term = ?', (term,))
        rows = cursor.fetchall()

        for doc_id, tf in rows:
            if doc_id not in df.index: continue

            doc_len = df.at[doc_id, 'doc_length']
            num = tf * (k1 + 1)
            den = tf + k1 * (1 - b + b * (doc_len / avg_dl))
            scores[doc_id] = scores.get(doc_id, 0.0) + idf * (num / den)
    return scores

valid_qids = []
for qid, docs in qrels_dict.items():
    if qid in queries_map and any(d in df.index for d in docs):
        valid_qids.append(qid)

if not valid_qids:
    print("오류: 유효한 쿼리를 찾을 수 없습니다.")
else:
    num_samples = min(10, len(valid_qids))
    test_qids = random.sample(valid_qids, num_samples)

    print(f"총 {num_samples}개의 쿼리에 대해 진단\n")

    for idx, test_qid in enumerate(test_qids):
        print("-" * 80)
        print(f"[CASE {idx + 1} / {num_samples}]")

        query_text = queries_map[test_qid]
        q_tokens = tokenize_query(query_text)
        target_docs = qrels_dict.get(test_qid, set())
        valid_targets = [d for d in target_docs if d in df.index]

        print(f"ID: {test_qid}")
        print(f"내용: {query_text}")
        print(f"토큰: {q_tokens}")
        print(f"정답 문서: {len(target_docs)}개 (샘플 내: {len(valid_targets)}개)")

        scores = calculate_scores(q_tokens, k1=5.5, b=0.99)
        ranked = sorted(scores.items(), key=lambda x: x[1], reverse=True)
        top_10 = ranked[:10]

        print("\n1. 상위 검색 결과 (Top 10)")
        print(f"{'순위':<4} {'점수':<8} {'문서ID':<15} {'토픽':<6} {'확률':<6} {'정답':<4} {'미리보기'}")

        ranked_ids = [d for d, s in ranked]

        for i, (doc_id, score) in enumerate(top_10):
            is_hit = "O" if doc_id in target_docs else "X"
            doc_topic = np.argmax(df.at[doc_id, 'topic_probs'])
            doc_prob = df.at[doc_id, 'topic_probs'][doc_topic]
            full_text = df.at[doc_id, 'text']
            title = df.at[doc_id, 'title'] if 'title' in df.columns else full_text[:20]
            preview = str(title).replace('\n', ' ')[:25]

            print(f"{i+1:<4} {score:<8.2f} {doc_id:<15} {doc_topic:<6} {doc_prob:<6.2f} {is_hit:<4} {preview}")

        print("\n2. 정답 문서 분석 (Ground Truth)")
        print(f"{'문서ID':<15} {'토픽':<6} {'확률':<6} {'검색순위'}")

        rel_topics = []
        for doc_id in list(valid_targets)[:5]:
            doc_topic = np.argmax(df.at[doc_id, 'topic_probs'])
            doc_prob = df.at[doc_id, 'topic_probs'][doc_topic]
            rel_topics.append(doc_topic)

            try:
                rank = ranked_ids.index(doc_id) + 1
            except ValueError:
                rank = "순위밖"

            print(f"{doc_id:<15} {doc_topic:<6} {doc_prob:<6.2f} {rank}")

        print("\n3. 진단 및 해석")
        unique_topics = set(rel_topics)
        if len(unique_topics) > 1:
            print(f"- 토픽 불일치: 정답 문서들이 서로 다른 토픽 {unique_topics}을 가짐.")
            print("  → 해석: 정답 간 공통된 토픽이 없으므로, 토픽 가중치가 0이 됨.")
        elif len(unique_topics) == 1:
            print(f"- 토픽 일치: 정답 문서들이 동일한 토픽 {unique_topics}을 가짐.")
            print("  → 해석: 그럼에도 오답 문서들과의 변별력이 없다면 토픽 정보는 무용지물")

        found_count = sum(1 for d in valid_targets if d in ranked_ids[:10])
        if found_count > 0:
            print(f"- 검색 성능: 정답 {len(valid_targets)}개 중 {found_count}개가 Top 10에 포함됨. (BM25 유효)")
        else:
            print(f"- 검색 성능: Top 10에 정답 없음. (키워드 불일치 또는 어휘 불일치 가능성)")

        print("\n")

conn.close()
# Out:
# 총 10개의 쿼리에 대해 진단
#
# --------------------------------------------------------------------------------
# [CASE 1 / 10]
# ID: query_001403
# 내용: 얘들아, 브롤스타즈 젬 그랩에서 없어졌다가 다시 생긴 그 돌 광산 맵 이름 뭐였지? 복귀한 거 맞나요?
# 토큰: ['브롤스타즈', '랩', '없', '다시', '생기', '돌', '광산', '이름', '복귀', '맞']
# 정답 문서: 6개 (샘플 내: 5개)
#
# 1. 상위 검색 결과 (Top 10)
# 순위   점수       문서ID            토픽     확률     정답   미리보기
# 1    85.67    브롤스타즈/맵/흔들 광산   7      0.35   O    브롤스타즈/맵/흔들 광산
# 2    73.61    브롤스타즈/맵/암석 광산   2      0.63   O    브롤스타즈/맵/암석 광산
# 3    73.29    브롤스타즈/맵/수정 오락실  2      0.56   O    브롤스타즈/맵/수정 오락실
# 4    66.42    브롤스타즈/맵/선인장 함정  2      0.53   O    브롤스타즈/맵/선인장 함정
# 5    32.14    플래티나워매몬         2      0.44   X    플래티나워매몬
# 6    29.92    캐피탈리즘 랩         7      0.48   X    캐피탈리즘 랩
# 7    28.82    가라르광산           7      0.58   X    가라르광산
# 8    26.72    플래시 도타/맵        2      0.36   O    플래시 도타/맵
# 9    26.60    멘마(나루토)         3      0.86   X    멘마(나루토)
# 10   24.82    카트라이더 리그/에이스 결정전/기록 9      0.42   X    카트라이더 리그/에이스 결정전/기록
#
# 2. 정답 문서 분석 (Ground Truth)
# 문서ID            토픽     확률     검색순위
# 브롤스타즈/맵/암석 광산   2      0.63   2
# 플래시 도타/맵        2      0.36   8
# 브롤스타즈/맵/흔들 광산   7      0.35   1
# 브롤스타즈/맵/선인장 함정  2      0.53   4
# 브롤스타즈/맵/수정 오락실  2      0.56   3
#
# 3. 진단 및 해석
# - 토픽 불일치: 정답 문서들이 서로 다른 토픽 {np.int64(2), np.int64(7)}을 가짐.
#   → 해석: 정답 간 공통된 토픽이 없으므로, 토픽 가중치가 0이 됨.
# - 검색 성능: 정답 5개 중 5개가 Top 10에 포함됨. (BM25 유효)
#
#
# --------------------------------------------------------------------------------
# [CASE 2 / 10]
# ID: query_000416
# 내용: 정의당 세종시당 위원장
# 토큰: ['정의당', '세종시', '당', '위원장']
# 정답 문서: 2개 (샘플 내: 2개)
#
# 1. 상위 검색 결과 (Top 10)
# 순위   점수       문서ID            토픽     확률     정답   미리보기
# 1    87.30    이혁재(정치인)        8      0.80   O    이혁재(정치인)
# 2    70.87    정의당/제6기 전국동시당직선거 8      0.77   O    정의당/제6기 전국동시당직선거
# 3    41.47    제21대 국회의원 선거/선거 전 예상 8      0.63   X    제21대 국회의원 선거/선거 전 예상
# 4    37.78    전혜숙             8      0.98   X    전혜숙
# 5    33.35    제21대 국회의원 선거/지역별 결과/광주광역시 8      0.61   X    제21대 국회의원 선거/지역별 결과/광주광역시
# 6    31.28    제21대 국회의원 선거/주요 이슈 8      0.80   X    제21대 국회의원 선거/주요 이슈
# 7    30.87    김진배             8      0.88   X    김진배
# 8    29.23    더불어민주당/선거       8      0.73   X    더불어민주당/선거
# 9    28.25    정규헌             8      0.82   X    정규헌
# 10   28.12    신한민주당           8      0.81   X    신한민주당
#
# 2. 정답 문서 분석 (Ground Truth)
# 문서ID            토픽     확률     검색순위
# 정의당/제6기 전국동시당직선거 8      0.77   2
# 이혁재(정치인)        8      0.80   1
#
# 3. 진단 및 해석
# - 토픽 일치: 정답 문서들이 동일한 토픽 {np.int64(8)}을 가짐.
#   → 해석: 그럼에도 오답 문서들과의 변별력이 없다면 토픽 정보는 무용지물
# - 검색 성능: 정답 2개 중 2개가 Top 10에 포함됨. (BM25 유효)
#
#
# --------------------------------------------------------------------------------
# [CASE 3 / 10]
# ID: query_000642
# 내용: 형님들, 조선이 청나라 속국이 되었다는 건 알겠는데 그게 병자호란 때문인가요? 삼전도에서 무슨 일이 있었는지 기억이 가물가물하고 그 후에 관계가 어떻게 변했는지도 알려주세요 ㅜㅜ
# 토큰: ['형', '조선', '청나라', '속국', '되', '알', '병자호란', '삼전도', '일', '있', '기억', '가물가물', '후', '관계', '변하', '알리']
# 정답 문서: 17개 (샘플 내: 13개)
#
# 1. 상위 검색 결과 (Top 10)
# 순위   점수       문서ID            토픽     확률     정답   미리보기
# 1    91.10    삼전도의 굴욕         0      0.90   O    삼전도의 굴욕
# 2    83.79    김상헌(조선)         0      0.89   O    김상헌(조선)
# 3    75.56    삼전도비            0      0.83   O    삼전도비
# 4    71.09    한국-만주 관계        0      1.00   O    한국-만주 관계
# 5    70.93    명청교체기           0      1.00   O    명청교체기
# 6    70.49    병자호란            0      0.97   O    병자호란
# 7    70.47    조청상민수륙무역장정      0      0.88   O    조청상민수륙무역장정
# 8    66.74    조청관계            0      1.00   O    조청관계
# 9    61.32    북한-만주 관계        0      1.00   X    북한-만주 관계
# 10   54.34    몽어유해            0      1.00   O    몽어유해
#
# 2. 정답 문서 분석 (Ground Truth)
# 문서ID            토픽     확률     검색순위
# 한국-만주 관계        0      1.00   4
# 조청관계            0      1.00   8
# 삼전도비            0      0.83   3
# 사대주의            0      1.00   11
# 한중관계            0      0.77   46
#
# 3. 진단 및 해석
# - 토픽 일치: 정답 문서들이 동일한 토픽 {np.int64(0)}을 가짐.
#   → 해석: 그럼에도 오답 문서들과의 변별력이 없다면 토픽 정보는 무용지물
# - 검색 성능: 정답 13개 중 9개가 Top 10에 포함됨. (BM25 유효)
#
#
# --------------------------------------------------------------------------------
# [CASE 4 / 10]
# ID: query_000953
# 내용: 형님들, 군종신부 되려면 신학교 다닐 때 군대 갔다 와야 한다던데, 신부가 되고 나선 교구에서 랜덤으로 뽑아서 대위로 다시 군대 가야 한다는 말 맞나요? 몇 프로만 뽑는다던데 진짜임?
# 토큰: ['형', '군종', '신부', '되', '신학교', '다니', '때', '군대', '가', '오', '하', '신부', '되', '교구', '랜덤', '대위', '다시', '군대', '가', '말', '맞', '하', '진짜']
# 정답 문서: 4개 (샘플 내: 3개)
#
# 1. 상위 검색 결과 (Top 10)
# 순위   점수       문서ID            토픽     확률     정답   미리보기
# 1    173.88   군종 신부           0      0.78   O    군종 신부
# 2    109.45   재입대             0      0.61   O    재입대
# 3    97.30    군경력자            0      0.61   O    군경력자
# 4    70.55    병인박해            0      0.97   X    병인박해
# 5    65.94    새남터 성지          0      0.79   X    새남터 성지
# 6    64.62    정하상             0      0.93   X    정하상
# 7    64.18    치명자산 성지         0      0.62   X    치명자산 성지
# 8    60.32    조선의 천주교 박해      0      1.00   X    조선의 천주교 박해
# 9    56.60    세례성사            0      0.83   X    세례성사
# 10   56.32    목사              0      0.60   X    목사
#
# 2. 정답 문서 분석 (Ground Truth)
# 문서ID            토픽     확률     검색순위
# 군경력자            0      0.61   3
# 재입대             0      0.61   2
# 군종 신부           0      0.78   1
#
# 3. 진단 및 해석
# - 토픽 일치: 정답 문서들이 동일한 토픽 {np.int64(0)}을 가짐.
#   → 해석: 그럼에도 오답 문서들과의 변별력이 없다면 토픽 정보는 무용지물
# - 검색 성능: 정답 3개 중 3개가 Top 10에 포함됨. (BM25 유효)
#
#
# --------------------------------------------------------------------------------
# [CASE 5 / 10]
# ID: query_000672
# 내용: 형님들 ㅈㅅ, 그레텍에서 광석 5배로 처리하는 꿀팁 옛날에 있었던 거 같은데... 주석 가루랑 연료 조합 맞나요? 아는 분 좀 알려주셈
# 토큰: ['형', '그레텍', '광석', '배', '처리', '꿀', '팁', '옛날', '있', '같', '주석', '가루', '연료', '조합', '맞', '아', '좀', '알리']
# 정답 문서: 3개 (샘플 내: 3개)
#
# 1. 상위 검색 결과 (Top 10)
# 순위   점수       문서ID            토픽     확률     정답   미리보기
# 1    69.65    GregTech 5 Unofficial/고온 야금술 7      0.90   O    GregTech 5 Unofficial/고온
# 2    66.36    Mekanism        7      1.00   O    Mekanism
# 3    49.25    청동              6      0.56   X    청동
# 4    45.97    주석(원소)          6      0.45   X    주석(원소)
# 5    45.44    마인크래프트/팁/모드     7      0.98   X    마인크래프트/팁/모드
# 6    41.84    마인크래프트/모드/자바 에디션/기술 계열 7      0.94   O    마인크래프트/모드/자바 에디션/기술 계열
# 7    39.12    구리              7      0.37   X    구리
# 8    36.75    설탕              8      0.36   X    설탕
# 9    33.19    컴온              5      0.74   X    컴온
# 10   33.00    마인크래프트/튜토리얼     7      0.86   X    마인크래프트/튜토리얼
#
# 2. 정답 문서 분석 (Ground Truth)
# 문서ID            토픽     확률     검색순위
# 마인크래프트/모드/자바 에디션/기술 계열 7      0.94   6
# Mekanism        7      1.00   2
# GregTech 5 Unofficial/고온 야금술 7      0.90   1
#
# 3. 진단 및 해석
# - 토픽 일치: 정답 문서들이 동일한 토픽 {np.int64(7)}을 가짐.
#   → 해석: 그럼에도 오답 문서들과의 변별력이 없다면 토픽 정보는 무용지물
# - 검색 성능: 정답 3개 중 3개가 Top 10에 포함됨. (BM25 유효)
#
#
# --------------------------------------------------------------------------------
# [CASE 6 / 10]
# ID: query_000193
# 내용: 유로파 유니버셜리스 4에서 무역 가치는 어떤 방향으로 흐르나요?
# 토큰: ['유로파', '유니버셜', '리스', '무역', '가치', '방향', '흐르']
# 정답 문서: 3개 (샘플 내: 3개)
#
# 1. 상위 검색 결과 (Top 10)
# 순위   점수       문서ID            토픽     확률     정답   미리보기
# 1    46.09    Europa Universalis IV/무역 0      0.78   O    Europa Universalis IV/무역
# 2    36.12    에레디비시           4      0.96   X    에레디비시
# 3    32.54    Europa Universalis IV/예속국 0      0.78   O    Europa Universalis IV/예속국
# 4    29.94    WWE/월드 챔피언십     4      0.94   X    WWE/월드 챔피언십
# 5    26.19    Europa Universalis IV/공략/포르투갈 0      0.66   O    Europa Universalis IV/공략/
# 6    23.80    AFC 아약스/역사      4      1.00   X    AFC 아약스/역사
# 7    21.99    압둘라 더 부처        3      0.43   X    압둘라 더 부처
# 8    21.64    카를로스 바카         4      1.00   X    카를로스 바카
# 9    21.36    세비야 FC          4      1.00   X    세비야 FC
# 10   21.28    소그드인            0      1.00   X    소그드인
#
# 2. 정답 문서 분석 (Ground Truth)
# 문서ID            토픽     확률     검색순위
# Europa Universalis IV/예속국 0      0.78   3
# Europa Universalis IV/무역 0      0.78   1
# Europa Universalis IV/공략/포르투갈 0      0.66   5
#
# 3. 진단 및 해석
# - 토픽 일치: 정답 문서들이 동일한 토픽 {np.int64(0)}을 가짐.
#   → 해석: 그럼에도 오답 문서들과의 변별력이 없다면 토픽 정보는 무용지물
# - 검색 성능: 정답 3개 중 3개가 Top 10에 포함됨. (BM25 유효)
#
#
# --------------------------------------------------------------------------------
# [CASE 7 / 10]
# ID: query_000044
# 내용: 파이널 판타지 6 세리스 캐릭터 소개
# 토큰: ['파이널 판타지', '리스', '캐릭터', '소개']
# 정답 문서: 4개 (샘플 내: 4개)
#
# 1. 상위 검색 결과 (Top 10)
# 순위   점수       문서ID            토픽     확률     정답   미리보기
# 1    26.41    사가 시리즈          1      0.31   X    사가 시리즈
# 2    23.76    게임의 전통          2      0.34   X    게임의 전통
# 3    23.24    세리스             9      0.34   O    세리스
# 4    21.46    세리스 셰르          2      0.49   O    세리스 셰르
# 5    18.85    왕자/목록           3      0.50   X    왕자/목록
# 6    18.41    머리카락/녹색         3      0.64   X    머리카락/녹색
# 7    18.36    아라크니드(만화)/등장인물  3      0.89   X    아라크니드(만화)/등장인물
# 8    18.16    리스항구/빅뱅 이전      2      0.73   X    리스항구/빅뱅 이전
# 9    16.32    나제 터빈           3      0.87   X    나제 터빈
# 10   15.72    에스타롯사           2      0.63   X    에스타롯사
#
# 2. 정답 문서 분석 (Ground Truth)
# 문서ID            토픽     확률     검색순위
# 시어리즈            3      1.00   순위밖
# 세리스 셰르          2      0.49   4
# 사티아 세이룬         3      0.81   1131
# 세리스             9      0.34   3
#
# 3. 진단 및 해석
# - 토픽 불일치: 정답 문서들이 서로 다른 토픽 {np.int64(9), np.int64(2), np.int64(3)}을 가짐.
#   → 해석: 정답 간 공통된 토픽이 없으므로, 토픽 가중치가 0이 됨.
# - 검색 성능: 정답 4개 중 2개가 Top 10에 포함됨. (BM25 유효)
#
#
# --------------------------------------------------------------------------------
# [CASE 8 / 10]
# ID: query_000145
# 내용: 시크교도의 인사말은 무엇인가요?
# 토큰: ['시크교', '도', '인사말']
# 정답 문서: 1개 (샘플 내: 1개)
#
# 1. 상위 검색 결과 (Top 10)
# 순위   점수       문서ID            토픽     확률     정답   미리보기
# 1    51.59    시크교             0      0.79   O    시크교
# 2    17.68    인도/역사           0      1.00   X    인도/역사
# 3    17.61    현숙              5      0.76   X    현숙
# 4    14.79    마라타 동맹          0      0.96   X    마라타 동맹
# 5    9.91     조재원             5      0.96   X    조재원
# 6    9.25     씨발              9      0.49   X    씨발
# 7    8.90     오오쿠보 루미         5      0.52   X    오오쿠보 루미
# 8    8.38     코요태             5      0.98   X    코요태
# 9    8.13     팔도              6      0.50   X    팔도
# 10   8.09     23부제            0      0.51   X    23부제
#
# 2. 정답 문서 분석 (Ground Truth)
# 문서ID            토픽     확률     검색순위
# 시크교             0      0.79   1
#
# 3. 진단 및 해석
# - 토픽 일치: 정답 문서들이 동일한 토픽 {np.int64(0)}을 가짐.
#   → 해석: 그럼에도 오답 문서들과의 변별력이 없다면 토픽 정보는 무용지물
# - 검색 성능: 정답 1개 중 1개가 Top 10에 포함됨. (BM25 유효)
#
#
# --------------------------------------------------------------------------------
# [CASE 9 / 10]
# ID: query_000833
# 내용: 형님들 판여에서 피림이 '잠의 현자' 전직하는 거 어떻게 하는 거임? 돈 주고 했다던데 스킬이랑 수면 패널티 정보좀 ㅜㅜ 중간에 업글 조건도 궁금해
# 토큰: ['형', '판', '여', '피', '림', '잠', '현자', '전직', '하', '돈', '주', '하', '스킬', '수면', '패널티', '정보', '좀', '중간', '업', '글', '조건']
# 정답 문서: 3개 (샘플 내: 2개)
#
# 1. 상위 검색 결과 (Top 10)
# 순위   점수       문서ID            토픽     확률     정답   미리보기
# 1    113.34   판타지 여동생!/설정     2      0.95   O    판타지 여동생!/설정
# 2    107.21   판타지 여동생!        2      0.51   O    판타지 여동생!
# 3    61.19    로열 로드/직업        2      0.71   X    로열 로드/직업
# 4    48.09    마나카로 가자!!       2      0.99   X    마나카로 가자!!
# 5    47.12    파이어 엠블렘 각성/클래스  2      0.91   X    파이어 엠블렘 각성/클래스
# 6    46.81    이인도 타도 노부나가     2      0.52   X    이인도 타도 노부나가
# 7    46.52    슈퍼스타(드래곤 퀘스트)   2      0.86   X    슈퍼스타(드래곤 퀘스트)
# 8    44.83    던전 앤 파이터/아이템/봉  2      1.00   X    던전 앤 파이터/아이템/봉
# 9    42.09    노아(엘소드)/리버레이터   2      0.98   X    노아(엘소드)/리버레이터
# 10   38.95    크루세이더(던전 앤 파이터)/여자 2      0.90   X    크루세이더(던전 앤 파이터)/여자
#
# 2. 정답 문서 분석 (Ground Truth)
# 문서ID            토픽     확률     검색순위
# 판타지 여동생!/설정     2      0.95   1
# 판타지 여동생!        2      0.51   2
#
# 3. 진단 및 해석
# - 토픽 일치: 정답 문서들이 동일한 토픽 {np.int64(2)}을 가짐.
#   → 해석: 그럼에도 오답 문서들과의 변별력이 없다면 토픽 정보는 무용지물
# - 검색 성능: 정답 2개 중 2개가 Top 10에 포함됨. (BM25 유효)
#
#
# --------------------------------------------------------------------------------
# [CASE 10 / 10]
# ID: query_001007
# 내용: 안녕하세요, 2003년 잭 블랙이 출연한 코미디 영화를 찾고 있습니다. 임시 교사가 된 주인공이 아이들과 록 밴드를 결성하는 내용인데 제목이 기억나지 않아요. 도움 부탁드립니다.
# 토큰: ['안녕', '잭', '블랙', '출연', '코미디', '영화', '찾', '임시', '교사', '되', '주인공', '아이', '록', '밴드', '결성', '내용', '제목', '기억나', '도움', '부탁', '드리']
# 정답 문서: 2개 (샘플 내: 2개)
#
# 1. 상위 검색 결과 (Top 10)
# 순위   점수       문서ID            토픽     확률     정답   미리보기
# 1    97.13    스쿨 오브 락         5      0.48   O    스쿨 오브 락
# 2    84.57    잭 블랙            5      0.48   O    잭 블랙
# 3    61.61    잭 앤 질           3      0.57   X    잭 앤 질
# 4    55.43    YB              5      0.96   X    YB
# 5    53.88    로버트 패트릭         3      0.62   X    로버트 패트릭
# 6    53.51    장준환             5      0.43   X    장준환
# 7    50.03    나 어떡해           5      0.78   X    나 어떡해
# 8    49.50    오태호             5      1.00   X    오태호
# 9    48.93    김성균             5      0.81   X    김성균
# 10   44.94    쿠몬 카이토/작중 행적/본편 2      0.65   X    쿠몬 카이토/작중 행적/본편
#
# 2. 정답 문서 분석 (Ground Truth)
# 문서ID            토픽     확률     검색순위
# 잭 블랙            5      0.48   2
# 스쿨 오브 락         5      0.48   1
#
# 3. 진단 및 해석
# - 토픽 일치: 정답 문서들이 동일한 토픽 {np.int64(5)}을 가짐.
#   → 해석: 그럼에도 오답 문서들과의 변별력이 없다면 토픽 정보는 무용지물
# - 검색 성능: 정답 2개 중 2개가 Top 10에 포함됨. (BM25 유효)

# %% [markdown]
# # [검색 시스템 심층 진단 보고서] 토픽 가중치의 한계와 BM25의 우수성 분석
#
# ## 1. 개요
# 본 보고서는 전체 쿼리 중 무작위로 추출한 10개 케이스(Query)를 대상으로, **BM25 검색 결과(Rank)**와 **LDA 토픽 모델링 결과(Topic Probability)**를 정성적으로 분석한 결과이다. 이를 통해 통계적 회귀분석에서 도출된 **"토픽 가중치($a_3$) 0.0"**의 원인을 실제 데이터 수준에서 규명하고, 향후 검색 모델 개선 방향을 제안한다.
#
# ## 2. 케이스별 상세 분석
#
# 분석 결과, 대다수의 케이스에서 **BM25(키워드 매칭)만으로 정답을 상위권에 정확히 노출**시키는 데 성공했다. 반면, 토픽 정보는 정답과 오답을 구별하는 변별력(Discriminative Power)을 제공하지 못하는 것으로 확인되었다.
#
# ### **패턴 A: 토픽의 변별력 부재 (Low Discriminative Power) - 다수 발생**
# > **대상:** CASE 1(브롤스타즈), CASE 2(정의당), CASE 3(병자호란), CASE 4(군종신부), CASE 5(마인크래프트), CASE 6(유로파 유니버셜리스), CASE 9(판타지 여동생), CASE 10(스쿨 오브 락)
#
# 이 패턴은 정답 문서들이 특정 토픽에 일관되게 묶여 있음에도 불구하고, 토픽 가중치가 무용지물인 이유를 가장 잘 설명해준다.
#
# * **현상:** 정답 문서들이 동일한 토픽(예: Topic 2, 7, 8 등)을 공유하고 있어, 얼핏 보면 토픽 정보가 유효해 보인다. 그러나 **상위권에 랭크된 오답 문서들 역시 동일한 토픽을 공유**하고 있다.
#     * **CASE 1 (브롤스타즈):** 정답 문서들이 **Topic 2**와 **Topic 7**로 나뉘었으며, 오답인 '캐피탈리즘 랩'(Topic 7)이나 '플래티나워매몬'(Topic 2)도 같은 토픽을 공유하여 변별력이 없었다.
#     * **CASE 3 (병자호란):** 정답 문서('삼전도의 굴욕', '병자호란')가 **Topic 0**으로 분류되었으나, 오답 문서('북한-만주 관계', 9위) 역시 **Topic 0** (확률 1.00)으로 분류되었다. 만약 Topic 0에 가중치를 주었다면 오답 문서의 순위도 함께 상승했을 것이다.
#     * **CASE 4 (군종신부):** 정답 문서('군종 신부', '재입대')가 **Topic 0**이지만, 오답 문서('병인박해', '목사')도 모두 **Topic 0**으로 분류되었다. '종교/군사'라는 큰 범주 안에서는 정답과 오답을 구별할 수 없음을 보여준다.
#     * **CASE 10 (스쿨 오브 락):** 정답('스쿨 오브 락', '잭 블랙')이 **Topic 5**이지만, 오답('YB', '오태호' 등 가수 관련 문서)들도 **Topic 5**로 분류되어, 주제만으로는 영화와 가수를 구별하지 못했다.
#
# * **결론:** LDA 토픽은 문서를 거시적인 주제(역사, 게임, 인물 등)로 분류할 뿐, 사용자의 구체적인 질문 의도(Specific Intent)를 파악하지 못한다. 따라서 **토픽 가중치를 높이면 주제만 같고 내용은 다른 오답 문서들이 상위권에 난입하는 노이즈(Noise)가 발생**한다.
#
# ### **패턴 B: 토픽 불일치 (Topic Mismatch)**
# > **대상:** CASE 7 (포켓몬스터), CASE 8 (시크교)
#
# 이 패턴은 토픽 정보를 랭킹에 반영할 경우 치명적인 부작용이 발생할 수 있음을 보여준다.
#
# * **현상:** 하나의 질문에 대한 정답 문서들이 서로 다른 토픽으로 분류되거나, 정답 문서의 토픽 확률이 낮음에도 상위권에 랭크되는 경우이다.
#     * **CASE 7 (포켓몬스터):** 정답 문서들 간 토픽이 **Topic 2, 3, 9** 등으로 분산되었다. 특정 토픽에 가중치를 부여했다면, 다른 토픽을 가진 정답 문서들은 순위 밖으로 밀려났을 것이다.
#     * **CASE 8 (시크교):** 정답 문서('시크교')는 **Topic 0**이지만, 오답 문서('인도/역사') 역시 **Topic 0** (확률 1.00)으로 더 높은 토픽 확률을 가졌다. 토픽 확률에 의존했다면 오답이 정답보다 더 높은 점수를 받았을 것이다.
#
# * **결론:** 정답 문서 간의 **주제적 일관성(Consistency)이 결여**되어 있거나, 정답과 오답이 뒤섞여 있어 토픽 정보를 신뢰할 수 없다.
#
# ---
#
# ## 3. 종합 결론: 왜 $w_{topic} = 0$ 인가?
#
# 본 진단을 통해 **토픽 가중치($a_3$)가 0으로 수렴해야 하는 논리적 근거**가 확실해졌다.
#
# 1.  **변별력의 부재:** 주제(Topic) 정보는 정답과 오답을 가르는 필터 역할을 하지 못한다. 정답과 오답은 대부분 같은 주제 카테고리 안에 공존한다.
# 2.  **키워드(BM25)의 압도적 우위:** 10개 케이스 중 거의 모든 사례에서 **BM25 스코어만으로 정답 문서를 1~3위 내에 정확히 위치**시켰다.
#     * *예시:* CASE 5 (마인크래프트)에서 튜닝된 BM25는 '주석', '가루' 등의 세부 키워드를 정확히 매칭하여 정답 문서('GregTech 5...')를 1위로 끌어올렸다.
# 3.  **오히려 방해 요소:** 토픽 정보는 정답을 찾는 데 도움을 주기보다는, 주제적으로만 유사한 오답 문서를 상위권으로 끌어올리거나(패턴 A), 서로 다른 토픽을 가진 정답 문서를 누락시키는(패턴 B) **방해 요소(Distractor)**로 작용할 가능성이 크다.
#
# ---
#
# ## 4. 제언 (Future Work)
#
# 1.  **토픽 모델 제외 확정:** 현행 검색 모델에서 **LDA 토픽 확률은 랭킹 요소에서 배제**하는 것이 검색 품질 유지에 유리하다.
# 2.  **BM25 파라미터 최적화 유지:** 현재 튜닝된 파라미터($k_1=5.5, b=0.99$)는 10개 케이스 전반에 걸쳐 매우 우수한 성능을 보이고 있으므로, 이를 **최종 모델의 핵심 엔진으로 확정**한다.
# 3.  **검색 품질 향상 방향:** 향후 성능 개선을 위해서는 토픽 모델링보다는, 동의어 처리나 문맥을 파악할 수 있는 **임베딩 기반 검색(Vector Search)** 도입을 고려해야 한다. 이는 CASE 4, 7과 같이 키워드 매칭만으로는 일부 정답을 놓치는 경우를 보완해 줄 것이다.
